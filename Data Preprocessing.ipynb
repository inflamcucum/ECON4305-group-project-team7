# %% [markdown]
# # ECON 4305 Project
# # Data Cleaning

# %%
#Standard libraries
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from numpy import asarray
from pandas import read_csv
import time
sns.set(style='whitegrid', palette='muted')
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 14, 8

#Sklearn
from sklearn import metrics
from sklearn.metrics import make_scorer
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import SGDClassifier

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV

from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression

# %%
# Imports data
macro = pd.read_excel('US FRED-MD Macro Dataset.xlsx', sheet_name=1,header=0, index_col=0)
macro.shape
# Out:
# (773, 127)

# %%
macro.head
# Out:
# <bound method NDFrame.head of                   RPI  W875RX1  DPCERA3M086SBEA     CMRMTSPLx       RETAILx  \
# sasdate
# 1959-01-01   2442.158   2293.2           17.272  2.922664e+05   18235.77392
# 1959-01-02   2451.778   2301.5           17.452  2.944247e+05   18369.56308
# 1959-01-03   2467.594   2318.5           17.617  2.934187e+05   18523.05762
# 1959-01-04   2483.671   2334.9           17.553  2.993228e+05   18534.46600
# 1959-01-05   2498.026   2350.4           17.765  3.013643e+05   18679.66354
# ...               ...      ...              ...           ...           ...
# 2023-01-01  17821.000  14623.3          130.028  1.581882e+06  692501.00000
# 2023-01-02  17839.528  14622.7          129.991  1.575290e+06  687942.00000
# 2023-01-03  17885.887  14664.3          129.948  1.560472e+06  681673.00000
# 2023-01-04  17866.773  14659.0          130.255  1.556928e+06  684213.00000
# 2023-01-05  17915.688  14702.7          130.222           NaN  686573.00000
#
#               INDPRO   IPFPNSS   IPFINAL   IPCONGD  IPDCONGD  ...  \
# sasdate                                                       ...
# 1959-01-01   21.9665   23.3891   22.2688   31.7011   19.0149  ...
# 1959-01-02   22.3966   23.7048   22.4617   31.9337   19.1147  ...
# 1959-01-03   22.7193   23.8483   22.5719   31.9337   19.4890  ...
# 1959-01-04   23.2032   24.1927   22.9026   32.4374   19.6138  ...
# 1959-01-05   23.5528   24.3936   23.1231   32.5925   20.0130  ...
# ...              ...       ...       ...       ...       ...  ...
# 2023-01-01  102.5080  101.2863  101.3295  102.0755  104.8646  ...
# 2023-01-02  102.5023  101.0873  101.1983  102.1753  105.0877  ...
# 2023-01-03  102.6521  101.0102  101.1678  102.4580  103.9786  ...
# 2023-01-04  103.1748  101.7373  102.1572  103.4504  108.3743  ...
# 2023-01-05  103.0107  101.6856  102.0669  103.3327  108.7279  ...
#
#             DNDGRG3M086SBEA  DSERRG3M086SBEA  CES0600000008  CES2000000008  \
# sasdate
# 1959-01-01           17.791           11.326           2.13           2.45
# 1959-01-02           17.798           11.343           2.14           2.46
# 1959-01-03           17.785           11.363           2.15           2.45
# 1959-01-04           17.796           11.403           2.16           2.47
# 1959-01-05           17.777           11.421           2.17           2.48
# ...                     ...              ...            ...            ...
# 2023-01-01          114.885          134.903          28.91          33.44
# 2023-01-02          115.279          135.397          28.98          33.61
# 2023-01-03          114.930          135.782          29.12          33.79
# 2023-01-04          115.341          136.315          29.22          33.92
# 2023-01-05          114.944          136.665          29.36          34.07
#
#             CES3000000008  UMCSENTx  DTCOLNVHFNM   DTCTHFNM     INVEST  \
# sasdate
# 1959-01-01           2.04       NaN      6476.00   12298.00    84.2043
# 1959-01-02           2.05       NaN      6476.00   12298.00    83.5280
# 1959-01-03           2.07       NaN      6508.00   12349.00    81.6405
# 1959-01-04           2.08       NaN      6620.00   12484.00    81.8099
# 1959-01-05           2.08      95.3      6753.00   12646.00    80.7315
# ...                   ...       ...          ...        ...        ...
# 2023-01-01          25.82      64.9    383384.74  720635.04  5505.6964
# 2023-01-02          25.81      67.0    385165.01  718917.35  5491.3981
# 2023-01-03          25.95      62.0    388912.72  719670.11  5366.2449
# 2023-01-04          26.03      63.5    390133.21  720155.25  5250.7099
# 2023-01-05          26.19      59.2          NaN        NaN  5220.8945
#
#             VIXCLSx
# sasdate
# 1959-01-01      NaN
# 1959-01-02      NaN
# 1959-01-03      NaN
# 1959-01-04      NaN
# 1959-01-05      NaN
# ...             ...
# 2023-01-01  20.2269
# 2023-01-02  20.2141
# 2023-01-03  22.0446
# 2023-01-04  17.4930
# 2023-01-05  17.3964
#
# [773 rows x 127 columns]>

# %%
# Imports data
tran_code = pd.read_excel('US FRED-MD Macro Dataset.xlsx', sheet_name=0, header=0, index_col=1, usecols=[1,2]).T
tran_code.shape
# Out:
# (1, 127)

# %%
tran_code
# Out:
# fred   RPI  W875RX1  DPCERA3M086SBEA  CMRMTSPLx  RETAILx  INDPRO  IPFPNSS  \
# tcode    5        5                5          5        5       5        5
#
# fred   IPFINAL  IPCONGD  IPDCONGD  ...  DNDGRG3M086SBEA  DSERRG3M086SBEA  \
# tcode        5        5         5  ...                6                6
#
# fred   CES0600000008  CES2000000008  CES3000000008  UMCSENTx  DTCOLNVHFNM  \
# tcode              6              6              6         2            6
#
# fred   DTCTHFNM  INVEST  VIXCLSx
# tcode         6       6        1
#
# [1 rows x 127 columns]

# %%
def data_transform(x, tran_code):
    
    if tran_code == 1:
        x_tr = x        
        
    elif tran_code == 2:
        x_tr = x.diff()
            
    elif tran_code == 3:
        x_tr = x.diff().diff()
        
    elif tran_code == 4:
        x_tr = np.log(x)
        
    elif tran_code == 5:
        x_tr = np.log(x).diff()*100
    
    elif tran_code == 6:
        x_tr = np.log(x).diff().diff()*100
    
    elif tran_code == 7:
        x_tr = (x.pct_change()-1)*100
    return x_tr

# %%
macro["NONBORRES"].shift(1)
# Out:
# sasdate
# 1959-01-01          NaN
# 1959-01-02      18300.0
# 1959-01-03      18100.0
# 1959-01-04      17800.0
# 1959-01-05      18000.0
#                 ...
# 2023-01-01    3090000.0
# 2023-01-02    3014200.0
# 2023-01-03    3006200.0
# 2023-01-04    3043100.0
# 2023-01-05    2939800.0
# Name: NONBORRES, Length: 773, dtype: float64

# %%
macro_tr=[]

for col in macro.columns:
    tr_code = tran_code[col].values
    data_tr = data_transform(macro[col], tr_code)
    macro_tr.append(data_tr)

macro_tr = pd.DataFrame(macro_tr).T

# %%
macro_tr["NONBORRES"]
# Out:
# sasdate
# 1959-01-01           NaN
# 1959-01-02   -101.092896
# 1959-01-03   -101.657459
# 1959-01-04    -98.876404
# 1959-01-05   -101.111111
#                  ...
# 2023-01-01   -102.453074
# 2023-01-02   -100.265410
# 2023-01-03    -98.772537
# 2023-01-04   -103.394565
# 2023-01-05   -100.387781
# Name: NONBORRES, Length: 773, dtype: float64

# %%
# Imports data
Inflation = np.log(macro["CPIAUCSL"]).diff()*100

# %%
Inflation
# Out:
# sasdate
# 1959-01-01         NaN
# 1959-01-02   -0.034477
# 1959-01-03   -0.103502
# 1959-01-04    0.034513
# 1959-01-05    0.206825
#                 ...
# 2023-01-01    0.515742
# 2023-01-02    0.369323
# 2023-01-03    0.053028
# 2023-01-04    0.367109
# 2023-01-05    0.124049
# Name: CPIAUCSL, Length: 773, dtype: float64

# %%
macro_final = pd.concat([macro_tr, Inflation], axis=1)
macro_final.columns=[*macro_tr.columns,"Inflation"]
macro_final=macro_final.drop(["1959-01-01"]).fillna(method="ffill").dropna()

# %%
# Show rows and columns
print("Rows, Columns:");print(macro_final.shape);print("\n")

# Describe DataFrame columns
print("Columns:");print(macro_final.columns);print("\n")

# Show info on DataFrame
print("Info:");print(macro_final.info(max_cols=1000)); print("\n")

# Count Non-NA values
print("Non-NA:");print(macro_final.count()); print("\n")

# Show head
print("Head");print(macro_final.head()); print("\n")

# Show tail
print("Tail");print(macro_final.tail());print("\n")

# Show summary statistics
print("Summary statistics:");print(macro_final.describe());print("\n")
# Out:
# Rows, Columns:
# (375, 128)
#
#
# Columns:
# Index(['RPI', 'W875RX1', 'DPCERA3M086SBEA', 'CMRMTSPLx', 'RETAILx', 'INDPRO',
#        'IPFPNSS', 'IPFINAL', 'IPCONGD', 'IPDCONGD',
#        ...
#        'DSERRG3M086SBEA', 'CES0600000008', 'CES2000000008', 'CES3000000008',
#        'UMCSENTx', 'DTCOLNVHFNM', 'DTCTHFNM', 'INVEST', 'VIXCLSx',
#        'Inflation'],
#       dtype='object', length=128)
#
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 375 entries, 1992-01-03 to 2023-01-05
# Data columns (total 128 columns):
#  #    Column           Non-Null Count  Dtype
# ---   ------           --------------  -----
#  0    RPI              375 non-null    float64
#  1    W875RX1          375 non-null    float64
#  2    DPCERA3M086SBEA  375 non-null    float64
#  3    CMRMTSPLx        375 non-null    float64
#  4    RETAILx          375 non-null    float64
#  5    INDPRO           375 non-null    float64
#  6    IPFPNSS          375 non-null    float64
#  7    IPFINAL          375 non-null    float64
#  8    IPCONGD          375 non-null    float64
#  9    IPDCONGD         375 non-null    float64
#  10   IPNCONGD         375 non-null    float64
#  11   IPBUSEQ          375 non-null    float64
#  12   IPMAT            375 non-null    float64
#  13   IPDMAT           375 non-null    float64
#  14   IPNMAT           375 non-null    float64
#  15   IPMANSICS        375 non-null    float64
#  16   IPB51222S        375 non-null    float64
#  17   IPFUELS          375 non-null    float64
#  18   CUMFNS           375 non-null    float64
#  19   HWI              375 non-null    float64
#  20   HWIURATIO        375 non-null    float64
#  21   CLF16OV          375 non-null    float64
#  22   CE16OV           375 non-null    float64
#  23   UNRATE           375 non-null    float64
#  24   UEMPMEAN         375 non-null    float64
#  25   UEMPLT5          375 non-null    float64
#  26   UEMP5TO14        375 non-null    float64
#  27   UEMP15OV         375 non-null    float64
#  28   UEMP15T26        375 non-null    float64
#  29   UEMP27OV         375 non-null    float64
#  30   CLAIMSx          375 non-null    float64
#  31   PAYEMS           375 non-null    float64
#  32   USGOOD           375 non-null    float64
#  33   CES1021000001    375 non-null    float64
#  34   USCONS           375 non-null    float64
#  35   MANEMP           375 non-null    float64
#  36   DMANEMP          375 non-null    float64
#  37   NDMANEMP         375 non-null    float64
#  38   SRVPRD           375 non-null    float64
#  39   USTPU            375 non-null    float64
#  40   USWTRADE         375 non-null    float64
#  41   USTRADE          375 non-null    float64
#  42   USFIRE           375 non-null    float64
#  43   USGOVT           375 non-null    float64
#  44   CES0600000007    375 non-null    float64
#  45   AWOTMAN          375 non-null    float64
#  46   AWHMAN           375 non-null    float64
#  47   HOUST            375 non-null    float64
#  48   HOUSTNE          375 non-null    float64
#  49   HOUSTMW          375 non-null    float64
#  50   HOUSTS           375 non-null    float64
#  51   HOUSTW           375 non-null    float64
#  52   PERMIT           375 non-null    float64
#  53   PERMITNE         375 non-null    float64
#  54   PERMITMW         375 non-null    float64
#  55   PERMITS          375 non-null    float64
#  56   PERMITW          375 non-null    float64
#  57   ACOGNO           375 non-null    float64
#  58   AMDMNOx          375 non-null    float64
#  59   ANDENOx          375 non-null    float64
#  60   AMDMUOx          375 non-null    float64
#  61   BUSINVx          375 non-null    float64
#  62   ISRATIOx         375 non-null    float64
#  63   M1SL             375 non-null    float64
#  64   M2SL             375 non-null    float64
#  65   M2REAL           375 non-null    float64
#  66   BOGMBASE         375 non-null    float64
#  67   TOTRESNS         375 non-null    float64
#  68   NONBORRES        375 non-null    float64
#  69   BUSLOANS         375 non-null    float64
#  70   REALLN           375 non-null    float64
#  71   NONREVSL         375 non-null    float64
#  72   CONSPI           375 non-null    float64
#  73   S&P 500          375 non-null    float64
#  74   S&P: indust      375 non-null    float64
#  75   S&P div yield    375 non-null    float64
#  76   S&P PE ratio     375 non-null    float64
#  77   FEDFUNDS         375 non-null    float64
#  78   CP3Mx            375 non-null    float64
#  79   TB3MS            375 non-null    float64
#  80   TB6MS            375 non-null    float64
#  81   GS1              375 non-null    float64
#  82   GS5              375 non-null    float64
#  83   GS10             375 non-null    float64
#  84   AAA              375 non-null    float64
#  85   BAA              375 non-null    float64
#  86   COMPAPFFx        375 non-null    float64
#  87   TB3SMFFM         375 non-null    float64
#  88   TB6SMFFM         375 non-null    float64
#  89   T1YFFM           375 non-null    float64
#  90   T5YFFM           375 non-null    float64
#  91   T10YFFM          375 non-null    float64
#  92   AAAFFM           375 non-null    float64
#  93   BAAFFM           375 non-null    float64
#  94   TWEXAFEGSMTHx    375 non-null    float64
#  95   EXSZUSx          375 non-null    float64
#  96   EXJPUSx          375 non-null    float64
#  97   EXUSUKx          375 non-null    float64
#  98   EXCAUSx          375 non-null    float64
#  99   WPSFD49207       375 non-null    float64
#  100  WPSFD49502       375 non-null    float64
#  101  WPSID61          375 non-null    float64
#  102  WPSID62          375 non-null    float64
#  103  OILPRICEx        375 non-null    float64
#  104  PPICMM           375 non-null    float64
#  105  CPIAUCSL         375 non-null    float64
#  106  CPIAPPSL         375 non-null    float64
#  107  CPITRNSL         375 non-null    float64
#  108  CPIMEDSL         375 non-null    float64
#  109  CUSR0000SAC      375 non-null    float64
#  110  CUSR0000SAD      375 non-null    float64
#  111  CUSR0000SAS      375 non-null    float64
#  112  CPIULFSL         375 non-null    float64
#  113  CUSR0000SA0L2    375 non-null    float64
#  114  CUSR0000SA0L5    375 non-null    float64
#  115  PCEPI            375 non-null    float64
#  116  DDURRG3M086SBEA  375 non-null    float64
#  117  DNDGRG3M086SBEA  375 non-null    float64
#  118  DSERRG3M086SBEA  375 non-null    float64
#  119  CES0600000008    375 non-null    float64
#  120  CES2000000008    375 non-null    float64
#  121  CES3000000008    375 non-null    float64
#  122  UMCSENTx         375 non-null    float64
#  123  DTCOLNVHFNM      375 non-null    float64
#  124  DTCTHFNM         375 non-null    float64
#  125  INVEST           375 non-null    float64
#  126  VIXCLSx          375 non-null    float64
#  127  Inflation        375 non-null    float64
# dtypes: float64(128)
# memory usage: 377.9 KB
# None
#
#
# Non-NA:
# RPI                375
# W875RX1            375
# DPCERA3M086SBEA    375
# CMRMTSPLx          375
# RETAILx            375
#                   ...
# DTCOLNVHFNM        375
# DTCTHFNM           375
# INVEST             375
# VIXCLSx            375
# Inflation          375
# Length: 128, dtype: int64
#
#
# Head
#                  RPI   W875RX1  DPCERA3M086SBEA  CMRMTSPLx   RETAILx  \
# sasdate
# 1992-01-03  0.165313  0.081215         0.182407   0.401685 -0.300061
# 1992-01-04  0.373032  0.275060         0.083938   0.664201  0.601652
# 1992-01-05  0.532885  0.549297         0.514589  -0.873850  0.546742
# 1992-01-06  0.417254  0.444719         0.269590   1.048664  0.280383
# 1992-01-07 -0.079646 -0.134642         0.334203   1.330298  0.708002
#
#               INDPRO   IPFPNSS   IPFINAL   IPCONGD  IPDCONGD  ...  \
# sasdate                                                       ...
# 1992-01-03  0.834712  0.844191  0.887827  0.892907  2.035795  ...
# 1992-01-04  0.769184  0.748975  0.760298  0.940532  1.843950  ...
# 1992-01-05  0.324748  0.546363  0.580914  0.647050  3.074505  ...
# 1992-01-06  0.059695 -0.239920 -0.304895 -0.484071 -1.398611  ...
# 1992-01-07  0.893837  0.995847  1.126762  1.294361  2.614598  ...
#
#             DSERRG3M086SBEA  CES0600000008  CES2000000008  CES3000000008  \
# sasdate
# 1992-01-03        -0.019860       0.083645       1.166982      -0.355553
# 1992-01-04         0.077728       0.083014      -0.583570       0.175899
# 1992-01-05        -0.255295      -0.251432      -0.072648      -0.088998
# 1992-01-06         0.023712       0.250035       0.795664      -0.088298
# 1992-01-07         0.264845      -0.416910      -1.518733      -0.000307
#
#             UMCSENTx  DTCOLNVHFNM  DTCTHFNM    INVEST  VIXCLSx  Inflation
# sasdate
# 1992-01-03       7.2    -1.631311  0.166342 -0.383951  16.2227   0.360101
# 1992-01-04       1.2     3.714687 -0.584329  0.134978  16.1885   0.215440
# 1992-01-05       2.0    -5.294144  0.020679  0.410802  14.7280   0.214977
# 1992-01-06       1.2     4.562073  0.881246 -0.087417  14.7531   0.285919
# 1992-01-07      -3.8    -0.352309 -0.854378  0.216749  13.3036   0.285104
#
# [5 rows x 128 columns]
#
#
# Tail
#                  RPI   W875RX1  DPCERA3M086SBEA  CMRMTSPLx   RETAILx  \
# sasdate
# 2023-01-01  0.087570  0.130699         1.316033   0.190398  2.764501
# 2023-01-02  0.103913 -0.004103        -0.028459  -0.417590 -0.660515
# 2023-01-03  0.259530  0.284085        -0.033085  -0.945104 -0.915446
# 2023-01-04 -0.106924 -0.036149         0.235970  -0.227369  0.371920
# 2023-01-05  0.273402  0.297667        -0.025338  -0.227369  0.344328
#
#               INDPRO   IPFPNSS   IPFINAL   IPCONGD  IPDCONGD  ...  \
# sasdate                                                       ...
# 2023-01-01  1.003181  0.343776 -0.014901 -0.334291  0.217564  ...
# 2023-01-02 -0.005561 -0.196666 -0.129562  0.097723  0.212525  ...
# 2023-01-03  0.146036 -0.076300 -0.030143  0.276299 -1.061013  ...
# 2023-01-04  0.507904  0.717250  0.973228  0.963931  4.140587  ...
# 2023-01-05 -0.159177 -0.050830 -0.088432 -0.113839  0.325745  ...
#
#             DSERRG3M086SBEA  CES0600000008  CES2000000008  CES3000000008  \
# sasdate
# 2023-01-01         0.033243       0.170724      -0.004386       0.309575
# 2023-01-02        -0.224790      -0.417543      -0.152983      -0.621376
# 2023-01-03        -0.081575       0.240091       0.027041       0.579697
# 2023-01-04         0.107827      -0.139110      -0.150135      -0.233149
# 2023-01-05        -0.135343       0.135161       0.057251       0.304983
#
#             UMCSENTx  DTCOLNVHFNM  DTCTHFNM    INVEST  VIXCLSx  Inflation
# sasdate
# 2023-01-01       5.2     0.071035  0.049043 -0.142513  20.2269   0.515742
# 2023-01-02       2.1    -0.237727 -0.068985 -0.121427  20.2141   0.369323
# 2023-01-03      -5.0     0.505030  0.343295 -2.045412  22.0446   0.053028
# 2023-01-04       1.5    -0.654981 -0.037264  0.128939  17.4930   0.367109
# 2023-01-05      -4.3    -0.654981 -0.037264  1.607056  17.3964   0.124049
#
# [5 rows x 128 columns]
#
#
# Summary statistics:
#               RPI     W875RX1  DPCERA3M086SBEA   CMRMTSPLx     RETAILx  \
# count  375.000000  375.000000       375.000000  375.000000  375.000000
# mean     0.215520    0.202026         0.225666    0.190850    0.381480
# std      1.644681    0.784642         1.010070    1.214898    1.756461
# min    -14.565065   -6.056840       -12.799379  -12.889057  -15.809242
# 25%      0.007161   -0.029388         0.023042   -0.263943   -0.100340
# 50%      0.217967    0.244318         0.221694    0.211416    0.391249
# 75%      0.421696    0.466747         0.448083    0.735339    0.913302
# max     18.234919    4.012112         8.208242    7.732231   17.405309
#
#            INDPRO     IPFPNSS     IPFINAL     IPCONGD    IPDCONGD  ...  \
# count  375.000000  375.000000  375.000000  375.000000  375.000000  ...
# mean     0.135688    0.097974    0.105765    0.067255    0.168305  ...
# std      1.090312    1.113078    1.233082    1.147343    4.052974  ...
# min    -14.365634  -14.656939  -15.702967  -12.407525  -49.668255  ...
# 25%     -0.161445   -0.265844   -0.319953   -0.416744   -0.885107  ...
# 50%      0.194952    0.123305    0.113973    0.070348    0.217564  ...
# 75%      0.573173    0.555582    0.637135    0.557036    1.251570  ...
# max      6.298618    6.870275    8.287202    8.532604   35.663749  ...
#
#        DSERRG3M086SBEA  CES0600000008  CES2000000008  CES3000000008  \
# count       375.000000     375.000000     375.000000     375.000000
# mean         -0.000161       0.000826       0.002539       0.000214
# std           0.168300       0.291894       0.601148       0.349015
# min          -0.944192      -1.442485      -2.236816      -1.194814
# 25%          -0.075626      -0.157030      -0.252693      -0.219866
# 50%          -0.005161      -0.000344      -0.001591      -0.000107
# 75%           0.072838       0.162635       0.248984       0.183562
# max           1.597500       1.362105       2.825882       1.908582
#
#          UMCSENTx  DTCOLNVHFNM    DTCTHFNM      INVEST     VIXCLSx   Inflation
# count  375.000000   375.000000  375.000000  375.000000  375.000000  375.000000
# mean    -0.025600    -0.000753   -0.001068   -0.004463   20.062469    0.208829
# std      4.050607     2.694272    2.518964    1.144508    8.271395    0.275750
# min    -17.300000   -17.590365  -25.956229   -8.470116   10.078500   -1.786409
# 25%     -2.300000    -0.753012   -0.397968   -0.577680   13.843500    0.077763
# 50%      0.000000     0.008328    0.009412    0.037220   17.783800    0.206016
# 75%      2.500000     0.692014    0.490116    0.488981   24.456250    0.328193
# max     12.000000    18.730787   25.805015    4.994849   62.964800    1.367456
#
# [8 rows x 128 columns]

# %%
#Define Data for Machine Learning

X_start = 1  
X_lag = 1

# Features and Target
X, y = macro_final.iloc[X_start:-X_lag,:-1], macro_final.iloc[X_start+X_lag:,127]

# %%
X
# Out:
#                  RPI   W875RX1  DPCERA3M086SBEA  CMRMTSPLx   RETAILx  \
# sasdate
# 1992-01-04  0.373032  0.275060         0.083938   0.664201  0.601652
# 1992-01-05  0.532885  0.549297         0.514589  -0.873850  0.546742
# 1992-01-06  0.417254  0.444719         0.269590   1.048664  0.280383
# 1992-01-07 -0.079646 -0.134642         0.334203   1.330298  0.708002
# 1992-01-08  0.386454  0.380539         0.246840  -1.603560  0.324124
# ...              ...       ...              ...        ...       ...
# 2022-01-12 -0.013781 -0.019171        -0.193846   1.490076 -0.719328
# 2023-01-01  0.087570  0.130699         1.316033   0.190398  2.764501
# 2023-01-02  0.103913 -0.004103        -0.028459  -0.417590 -0.660515
# 2023-01-03  0.259530  0.284085        -0.033085  -0.945104 -0.915446
# 2023-01-04 -0.106924 -0.036149         0.235970  -0.227369  0.371920
#
#               INDPRO   IPFPNSS   IPFINAL   IPCONGD  IPDCONGD  ...  \
# sasdate                                                       ...
# 1992-01-04  0.769184  0.748975  0.760298  0.940532  1.843950  ...
# 1992-01-05  0.324748  0.546363  0.580914  0.647050  3.074505  ...
# 1992-01-06  0.059695 -0.239920 -0.304895 -0.484071 -1.398611  ...
# 1992-01-07  0.893837  0.995847  1.126762  1.294361  2.614598  ...
# 1992-01-08 -0.549192 -0.106279 -0.111965  0.036867 -0.863906  ...
# ...              ...       ...       ...       ...       ...  ...
# 2022-01-12 -1.550613 -1.202485 -0.846966 -0.623823 -1.031771  ...
# 2023-01-01  1.003181  0.343776 -0.014901 -0.334291  0.217564  ...
# 2023-01-02 -0.005561 -0.196666 -0.129562  0.097723  0.212525  ...
# 2023-01-03  0.146036 -0.076300 -0.030143  0.276299 -1.061013  ...
# 2023-01-04  0.507904  0.717250  0.973228  0.963931  4.140587  ...
#
#             DNDGRG3M086SBEA  DSERRG3M086SBEA  CES0600000008  CES2000000008  \
# sasdate
# 1992-01-04        -0.215571         0.077728       0.083014      -0.583570
# 1992-01-05         0.097556        -0.255295      -0.251432      -0.072648
# 1992-01-06         0.318864         0.023712       0.250035       0.795664
# 1992-01-07        -0.233369         0.264845      -0.416910      -1.518733
# 1992-01-08        -0.032213        -0.285966       0.499100       1.157537
# ...                     ...              ...            ...            ...
# 2022-01-12        -0.613838         0.175427      -0.107940       0.300155
# 2023-01-01         1.425376         0.033243       0.170724      -0.004386
# 2023-01-02        -0.416042        -0.224790      -0.417543      -0.152983
# 2023-01-03        -0.645568        -0.081575       0.240091       0.027041
# 2023-01-04         0.660174         0.107827      -0.139110      -0.150135
#
#             CES3000000008  UMCSENTx  DTCOLNVHFNM  DTCTHFNM    INVEST  VIXCLSx
# sasdate
# 1992-01-04       0.175899       1.2     3.714687 -0.584329  0.134978  16.1885
# 1992-01-05      -0.088998       2.0    -5.294144  0.020679  0.410802  14.7280
# 1992-01-06      -0.088298       1.2     4.562073  0.881246 -0.087417  14.7531
# 1992-01-07      -0.000307      -3.8    -0.352309 -0.854378  0.216749  13.3036
# 1992-01-08       0.086992      -0.5    -0.633643  1.163376  0.042164  14.4223
# ...                   ...       ...          ...       ...       ...      ...
# 2022-01-12      -0.590025       2.9    -0.283245 -0.123254  0.880929  21.7702
# 2023-01-01       0.309575       5.2     0.071035  0.049043 -0.142513  20.2269
# 2023-01-02      -0.621376       2.1    -0.237727 -0.068985 -0.121427  20.2141
# 2023-01-03       0.579697      -5.0     0.505030  0.343295 -2.045412  22.0446
# 2023-01-04      -0.233149       1.5    -0.654981 -0.037264  0.128939  17.4930
#
# [373 rows x 127 columns]

# %%
y
# Out:
# sasdate
# 1992-01-05    0.214977
# 1992-01-06    0.285919
# 1992-01-07    0.285104
# 1992-01-08    0.213295
# 1992-01-09    0.212842
#                 ...
# 2023-01-01    0.515742
# 2023-01-02    0.369323
# 2023-01-03    0.053028
# 2023-01-04    0.367109
# 2023-01-05    0.124049
# Name: Inflation, Length: 373, dtype: float64

# %%
import os  
os.makedirs('Data preprocess', exist_ok=True)  
X.to_csv('Data preprocess/x.csv') 

y.to_csv('Data preprocess/y.csv')
